# %% [markdown]
# ___
# ### Import libraries and sub-libraries.

# %%
import os
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.transforms import functional as TF
import tifffile 
from skimage.metrics import structural_similarity as ssim

# %% [markdown]
# ___
# ### Calling a custom code to change the default font for figures to `Computer Modern`. (Optional)

# %%
# from fontsetting import font_cmu
# plt = font_cmu(plt)

# %% [markdown]
# ___
# ### Check the hardware that is at your disposal

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device available:', device)
is_cuda = device.type == 'cuda'
# Out:
# Device available: cpu

# %% [markdown]
# ___
# ### Read training data from `data/train-clean-tif`

# %%
# Loading TIFF images
class TIFFDataset(Dataset):
    def __init__(self, directory, transform=None):
        self.directory = directory
        self.transform = transform
        self.filenames = [f for f in os.listdir(directory) if f.endswith('.tif')]

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):
        img_path = os.path.join(self.directory, self.filenames[idx])
        image = Image.open(img_path)
        if self.transform: # Dynamically apply data transformation
            image = self.transform(image)
        return image

# Create a transform to convert the images to PyTorch tensors
transform = transforms.Compose([
    transforms.ToTensor()
])

train_transform = transforms.Compose([
    transforms.RandomAffine(degrees=0,translate=(0.1,0.1)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

# Create the dataset for training images
train_dataset = TIFFDataset('train-clean-tif', transform=train_transform)
val_dataset = TIFFDataset('val-clean-tif', transform=transform) # Create the dataset for validation images

# Function to create data loader
def create_loader(train_dataset, batch_size):
    torch.manual_seed(0)  # For reproducibility of random numbers in PyTorch
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)  # Creates a training DataLoader from this Dataset
    return train_loader

dataset_size = len(train_dataset), len(val_dataset)
print('Number of images in the training dataset:', dataset_size[0])
print('Number of images in the validation dataset:', dataset_size[1])
# Out:
# Number of images in the training dataset: 52
# Number of images in the validation dataset: 16

# %% [markdown]
# ### Define a denoising network
#
# #### Here, I have defined a trivial network, which has only one convolutional layer and no activation function. We are essentially doing linear filtering.

# %%
class TrivialNet(nn.Module):
    def __init__(self):
        super(TrivialNet, self).__init__()
        self.relu = nn.ReLU()
        
        # Encoder Section
        # layer 1
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1) # output 256x256
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1) # output 256x256

        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2) # output 128x128
        self.bn1 = nn.BatchNorm2d(64)
        self.dropout1 = nn.Dropout(0.2)

        # layer 2
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1) # output 128x128
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1) # output 128x128
        
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2) # output 64x64
        self.bn2 = nn.BatchNorm2d(128)
        self.dropout2 = nn.Dropout(0.2)

        # layer 3
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1) # output 64x64
        self.conv6 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1) # output 64x64

        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2) # output 32x32
        self.bn3 = nn.BatchNorm2d(256)
        self.dropout3 = nn.Dropout(0.2)

        # layer 4
        self.conv7 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1) # output 32x32
        self.conv8 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1) # output 32x32

        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2) # output 16x16
        self.bn4 = nn.BatchNorm2d(512)
        self.dropout4 = nn.Dropout(0.2)
        
        # layer 5
        self.conv9 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, padding=1) # output 16x16
        self.conv10 = nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, padding=1) # output 16x16

        # Decoder Section
        self.up1 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2) # output 32x32
        self.bn5 = nn.BatchNorm2d(512)
        self.dropout5 = nn.Dropout(0.2)

        # layer 4
        self.conv11 = nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=3, padding=1) # output 32x32; still using 1024 channels because of concatenation
        self.conv12 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1) # output 32x32
        
        self.up2 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2) # output 64x64
        self.bn6 = nn.BatchNorm2d(256)
        self.dropout6 = nn.Dropout(0.2)

        # layer 3
        self.conv13 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=3, padding=1) # output 64x64; still using 512 channels because of concatenation
        self.conv14 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1) # output 64x64

        self.up3 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2) # output 128x128
        self.bn7 = nn.BatchNorm2d(128)
        self.dropout7 = nn.Dropout(0.2)

        # layer 2
        self.conv15 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=3, padding=1) # output 128x128; still using 256 channels because of concatenation
        self.conv16 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1) # output 128x128

        self.up4 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2) # output 256x256
        self.bn8 = nn.BatchNorm2d(64)
        self.dropout8 = nn.Dropout(0.2)

        # layer 1
        self.conv17 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3, padding=1) # output 256x256; still using 128 channels because of concatenation
        self.conv18 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1) # output 256x256

        # Output layer
        self.conv19 = nn.Conv2d(in_channels=64, out_channels=1, kernel_size=1, padding=0) # output 256x256



    def forward(self, x):
        x11 = self.relu(self.conv1(x))
        x12 = self.relu(self.conv2(x11))

        x2 = self.bn1(self.pool1(x12))
        x21 = self.relu(self.conv3(x2))
        x22 = self.relu(self.conv4(x21))

        x3 = self.bn2(self.pool2(x22))
        x31 = self.relu(self.conv5(x3))
        x32 = self.relu(self.conv6(x31))

        x4 = self.bn3(self.pool3(x32))
        x41 = self.relu(self.conv7(x4))
        x42 = self.relu(self.conv8(x41))

        x5 = self.bn4(self.pool4(x42))
        x51 = self.relu(self.conv9(x5))
        x52 = self.relu(self.conv10(x51))

        x6 = self.bn5(self.up1(x52))
        x6 = torch.cat((x6, x42), dim=1)
        x61 = self.relu(self.conv11(x6))
        x62 = self.relu(self.conv12(x61))

        x7 = self.bn6(self.up2(x62))
        x7 = torch.cat((x7, x32), dim=1)
        x71 = self.relu(self.conv13(x7))
        x72 = self.relu(self.conv14(x71))

        x8 = self.bn7(self.up3(x72))
        x8 = torch.cat((x8, x22), dim=1)
        x81 = self.relu(self.conv15(x8))
        x82 = self.relu(self.conv16(x81))

        x9 = self.bn8(self.up4(x82))
        x9 = torch.cat((x9, x12), dim=1)
        x91 = self.relu(self.conv17(x9))
        x92 = self.relu(self.conv18(x91))

        x = self.conv19(x92)
        
        return x

# %% [markdown]
# ___
# ### Create a function to execute training. Note, we will call this function later.

# %%
def train_model(model, opt, criterion, train_loader, test_loader, num_epoch, noise_std, avg_train_losses=[], avg_test_losses=[], epoch=0):

    for epoch in range(epoch, num_epoch): # Loop over the dataset multiple times
        model.train()
        total_train_loss = 0
        for i, y_tr_batch in enumerate(train_loader): # Loop over mini-batches
            if is_cuda:
                y_tr_batch = y_tr_batch.to(device) #GPU STUFF

            # Normalize y_tr_batch
            y_tr_batch_min, y_tr_batch_max = y_tr_batch.min(), y_tr_batch.max()
            y_tr_batch = (y_tr_batch - y_tr_batch_min) / (y_tr_batch_max - y_tr_batch_min)

            x_tr_batch = y_tr_batch.clone()
            noise = torch.randn_like(y_tr_batch) * noise_std
            x_tr_batch = x_tr_batch + noise

            opt.zero_grad() # delete previous gradients
            y_hat_tr_batch = model(x_tr_batch) # forward pass
            loss = criterion(y_hat_tr_batch, y_tr_batch) # compute loss
            loss.backward() # backward pass
            opt.step() # update weights
            total_train_loss += loss.item() # accumulate loss

        avg_train_loss = total_train_loss / len(train_loader) # compute average loss
        avg_train_losses.append(avg_train_loss) # accumulate average loss
        
        # Testing
        model.eval()
        with torch.no_grad():
            total_test_loss = 0
            for i, y_te_batch in enumerate(test_loader):
                if is_cuda:
                    y_te_batch= y_te_batch.to(device)#GPU STUFF

                # Normalize y_te_batch
                y_te_batch_min, y_te_batch_max = y_te_batch.min(), y_te_batch.max()
                y_te_batch = (y_te_batch - y_te_batch_min) / (y_te_batch_max - y_te_batch_min)

                noise = torch.randn_like(y_te_batch) * noise_std
                x_te_batch = y_te_batch + noise

                y_hat_te_batch = model(x_te_batch)
                loss = criterion(y_hat_te_batch, y_te_batch)
                total_test_loss += loss.item()
            avg_test_loss = total_test_loss / len(test_loader)
            print(f'Epoch {epoch+1}, Test Loss: {avg_test_loss:.6f}, Train Loss: {avg_train_loss:.6f}')
            avg_test_losses.append(avg_test_loss)

        # Save the model and optimizer state
        if (epoch + 1) % 10 == 0:
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': opt.state_dict(),
                'avg_train_losses': avg_train_losses[0:epoch],
                'avg_test_losses': avg_test_losses[0:epoch]
            }, 'model_checkpoint.pt')

    print('Length of Training loss', len(avg_test_losses))
    print('Length of Testing loss:', len(avg_test_losses))
    # Plotting
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.plot(range(1, num_epoch+1), avg_train_losses, label='training loss')
    ax.plot(range(1, num_epoch+1), avg_test_losses, label='testing loss')
    ax.plot()
    ax.set_xlabel('epochs')
    ax.set_ylabel('NMSE loss')
    ax.set_title('training loss')
    ax.legend(['training accuracy', 'test accuracy'])
    ax.grid(True)
    ax.legend()
    plt.show()

# %% [markdown]
# ___
# ### Now, let us define hyperparameters and train the network.
#
# #### Note, in addition to the parameters that controls the network architecture or the training process, you need to select/initialize (i) a data loader, (ii) a model, (iii) an optimizer, and (iv) a loss function.

# %%
batch_size = 1  # Number of complete images in each batch
lr = 1e-3  # Learning rate
sig = 0.1  # Noise std
num_epoch = 250  # Epochs

# Create a test loader (using validation for testing)
test_loader = create_loader(val_dataset, batch_size)

# %%
def SSIM_L1_loss(output, target):
    # print(f"Output shape: {output.shape}, Target shape: {target.shape}")  # Print the shapes of the output and target tensors

    l1_loss = nn.L1Loss()
    output_np = output.detach().squeeze().numpy()
    target_np = target.detach().squeeze().numpy()
    # print(f"Output shape: {output_np.shape}, Target shape: {target_np.shape}")  # Print the shapes of the output and target tensors

    ssim_loss = 1 - ssim(output_np.squeeze(), target_np.squeeze(), data_range=1, multichannel=True)
    ssim_loss = torch.tensor(ssim_loss, requires_grad=True).to(output.device)
    return l1_loss(output, target) + ssim_loss

# %%
# Initilize the model, criterion, and optimizer

# Model, criterion, and optimizer
train_loader = create_loader(train_dataset, batch_size)
model = TrivialNet() # Pick a model
if is_cuda:
    model = model.to(device)
opt = optim.Adam(model.parameters(), lr=lr) # Pick an optimizer
# criterion = nn.MSELoss() # Pick a loss function
# criterion = nmse_loss
criterion = SSIM_L1_loss
avg_train_losses = []
avg_test_losses = []
epoch = 0

# %%
# Checks to see if there is a checkpoint file, if there is, it will load the model and optimizer state

# load in checkpoint if it exists and train
if os.path.exists('model_checkpoint.pt'):
    checkpoint = torch.load('model_checkpoint.pt')
    model.load_state_dict(checkpoint['model_state_dict'])
    opt.load_state_dict(checkpoint['optimizer_state_dict'])
    avg_train_losses = checkpoint['avg_train_losses']
    avg_test_losses = checkpoint['avg_test_losses']
    epoch = checkpoint['epoch']
    print('Model loaded from checkpoint at epoch', checkpoint['epoch'])
    print('Length of Training loss', len(avg_test_losses))
    print('Length of Testing loss:', len(avg_test_losses))
# Out:
# Model loaded from checkpoint at epoch 99
# Length of Training loss 99
# Length of Testing loss: 99

# %%
# train model (from scratch or a checkpoint)
train_model(model, opt, criterion, train_loader, test_loader, num_epoch, sig, avg_train_losses, avg_test_losses, epoch)
# Out:
# Epoch 1, Test Loss: 0.330098, Train Loss: 0.478267
# Epoch 2, Test Loss: 0.275689, Train Loss: 0.272296
# Epoch 3, Test Loss: 0.220533, Train Loss: 0.247813
# Epoch 4, Test Loss: 0.215323, Train Loss: 0.224498
# Epoch 5, Test Loss: 0.193053, Train Loss: 0.206868
# Epoch 6, Test Loss: 0.235382, Train Loss: 0.204644
# Epoch 7, Test Loss: 0.194243, Train Loss: 0.206226
# Epoch 8, Test Loss: 0.194355, Train Loss: 0.201979
# Epoch 9, Test Loss: 0.197547, Train Loss: 0.197699
# Epoch 10, Test Loss: 0.214848, Train Loss: 0.197056
# Epoch 11, Test Loss: 0.205124, Train Loss: 0.194952
# Epoch 12, Test Loss: 0.189047, Train Loss: 0.195350
# Epoch 13, Test Loss: 0.206622, Train Loss: 0.187550
# Epoch 14, Test Loss: 0.181181, Train Loss: 0.181898
# Epoch 15, Test Loss: 0.181808, Train Loss: 0.174176
# Epoch 16, Test Loss: 0.174264, Train Loss: 0.185289
# Epoch 17, Test Loss: 0.185720, Train Loss: 0.175081
# Epoch 18, Test Loss: 0.170761, Train Loss: 0.172568
# Epoch 19, Test Loss: 0.203913, Train Loss: 0.172198
# Epoch 20, Test Loss: 0.168106, Train Loss: 0.167297
# Epoch 21, Test Loss: 0.169036, Train Loss: 0.165128
# Epoch 22, Test Loss: 0.166067, Train Loss: 0.166527
# Epoch 23, Test Loss: 0.170058, Train Loss: 0.162109
# Epoch 24, Test Loss: 0.166648, Train Loss: 0.157751
# Epoch 25, Test Loss: 0.168720, Train Loss: 0.162739
# Epoch 26, Test Loss: 0.167639, Train Loss: 0.162610
# Epoch 27, Test Loss: 0.183403, Train Loss: 0.158046
# Epoch 28, Test Loss: 0.162282, Train Loss: 0.157606
# Epoch 29, Test Loss: 0.177152, Train Loss: 0.158685
# Epoch 30, Test Loss: 0.173523, Train Loss: 0.158569
# Epoch 31, Test Loss: 0.166136, Train Loss: 0.157239
# Epoch 32, Test Loss: 0.171449, Train Loss: 0.154928
# Epoch 33, Test Loss: 0.158697, Train Loss: 0.154070
# Epoch 34, Test Loss: 0.193795, Train Loss: 0.149917
# Epoch 35, Test Loss: 0.157450, Train Loss: 0.150488
# Epoch 36, Test Loss: 0.168967, Train Loss: 0.151570
# Epoch 37, Test Loss: 0.159957, Train Loss: 0.151719
# Epoch 38, Test Loss: 0.152642, Train Loss: 0.152955
# Epoch 39, Test Loss: 0.152950, Train Loss: 0.149376
# Epoch 40, Test Loss: 0.157707, Train Loss: 0.147699
# Epoch 41, Test Loss: 0.155843, Train Loss: 0.151155
# Epoch 42, Test Loss: 0.161228, Train Loss: 0.147257
# Epoch 43, Test Loss: 0.153148, Train Loss: 0.144803
# Epoch 44, Test Loss: 0.166273, Train Loss: 0.148560
# Epoch 45, Test Loss: 0.162751, Train Loss: 0.145114
# Epoch 46, Test Loss: 0.154037, Train Loss: 0.147102
# Epoch 47, Test Loss: 0.157983, Train Loss: 0.146811
# Epoch 48, Test Loss: 0.151615, Train Loss: 0.144812
# Epoch 49, Test Loss: 0.157418, Train Loss: 0.145303
# Epoch 50, Test Loss: 0.172272, Train Loss: 0.147715
# Epoch 51, Test Loss: 0.166514, Train Loss: 0.148442
# Epoch 52, Test Loss: 0.178652, Train Loss: 0.148691
# Epoch 53, Test Loss: 0.150705, Train Loss: 0.145513
# Epoch 54, Test Loss: 0.163034, Train Loss: 0.143398
# Epoch 55, Test Loss: 0.147547, Train Loss: 0.141392
# Epoch 56, Test Loss: 0.155503, Train Loss: 0.140759
# Epoch 57, Test Loss: 0.149400, Train Loss: 0.142216
# Epoch 58, Test Loss: 0.155402, Train Loss: 0.143538
# Epoch 59, Test Loss: 0.159796, Train Loss: 0.141828
# Epoch 60, Test Loss: 0.152221, Train Loss: 0.139655
# Epoch 61, Test Loss: 0.148135, Train Loss: 0.141227
# Epoch 62, Test Loss: 0.152257, Train Loss: 0.138682
# Epoch 63, Test Loss: 0.166512, Train Loss: 0.140400
# Epoch 64, Test Loss: 0.149328, Train Loss: 0.139635
# Epoch 65, Test Loss: 0.151000, Train Loss: 0.139138
# Epoch 66, Test Loss: 0.153035, Train Loss: 0.140114
# Epoch 67, Test Loss: 0.150079, Train Loss: 0.140148
# Epoch 68, Test Loss: 0.150432, Train Loss: 0.139365
# Epoch 69, Test Loss: 0.177507, Train Loss: 0.146132
# Epoch 70, Test Loss: 0.152061, Train Loss: 0.141115
# Epoch 71, Test Loss: 0.152396, Train Loss: 0.138958
# Epoch 72, Test Loss: 0.146901, Train Loss: 0.138320
# Epoch 73, Test Loss: 0.148509, Train Loss: 0.138972
# Epoch 74, Test Loss: 0.147181, Train Loss: 0.142537
# Epoch 75, Test Loss: 0.149014, Train Loss: 0.136720
# Epoch 76, Test Loss: 0.169109, Train Loss: 0.140823
# Epoch 77, Test Loss: 0.156728, Train Loss: 0.138223
# Epoch 78, Test Loss: 0.148852, Train Loss: 0.137573
# Epoch 79, Test Loss: 0.146359, Train Loss: 0.135041
# Epoch 80, Test Loss: 0.156694, Train Loss: 0.138418
# Epoch 81, Test Loss: 0.152085, Train Loss: 0.135951
# Epoch 82, Test Loss: 0.150139, Train Loss: 0.138421
# Epoch 83, Test Loss: 0.149400, Train Loss: 0.136675
# Epoch 84, Test Loss: 0.145917, Train Loss: 0.138890
# Epoch 85, Test Loss: 0.149078, Train Loss: 0.136958
# Epoch 86, Test Loss: 0.146132, Train Loss: 0.133544
# Epoch 87, Test Loss: 0.154452, Train Loss: 0.137010
# Epoch 88, Test Loss: 0.155071, Train Loss: 0.136940
# Epoch 89, Test Loss: 0.146142, Train Loss: 0.137323
# Epoch 90, Test Loss: 0.147006, Train Loss: 0.135238
# Epoch 91, Test Loss: 0.142197, Train Loss: 0.134760
# Epoch 92, Test Loss: 0.147658, Train Loss: 0.134174
# Epoch 93, Test Loss: 0.152669, Train Loss: 0.134616
# Epoch 94, Test Loss: 0.144824, Train Loss: 0.133886
# Epoch 95, Test Loss: 0.164325, Train Loss: 0.134593
# Epoch 96, Test Loss: 0.142383, Train Loss: 0.134989
# Epoch 97, Test Loss: 0.145565, Train Loss: 0.132511
# Epoch 98, Test Loss: 0.148967, Train Loss: 0.132894
# Epoch 99, Test Loss: 0.148864, Train Loss: 0.132934
# Epoch 100, Test Loss: 0.144952, Train Loss: 0.133418
# Epoch 101, Test Loss: 0.154525, Train Loss: 0.133784
# Epoch 102, Test Loss: 0.144254, Train Loss: 0.131837
# Epoch 103, Test Loss: 0.143679, Train Loss: 0.135068
# Epoch 104, Test Loss: 0.147027, Train Loss: 0.135805
# Epoch 105, Test Loss: 0.150602, Train Loss: 0.136022
# Epoch 106, Test Loss: 0.150885, Train Loss: 0.135973
# Epoch 107, Test Loss: 0.144638, Train Loss: 0.131944
# Epoch 108, Test Loss: 0.147208, Train Loss: 0.132059
# Epoch 109, Test Loss: 0.144275, Train Loss: 0.133820
# Epoch 110, Test Loss: 0.145282, Train Loss: 0.132749
# Epoch 111, Test Loss: 0.144350, Train Loss: 0.133976
# Epoch 112, Test Loss: 0.147707, Train Loss: 0.132014
# Epoch 113, Test Loss: 0.145485, Train Loss: 0.130937
# Epoch 114, Test Loss: 0.141177, Train Loss: 0.137653
# Epoch 115, Test Loss: 0.152109, Train Loss: 0.131673
# Epoch 116, Test Loss: 0.145796, Train Loss: 0.132170
# Epoch 117, Test Loss: 0.147108, Train Loss: 0.133178
# Epoch 118, Test Loss: 0.140285, Train Loss: 0.130102
# Epoch 119, Test Loss: 0.145696, Train Loss: 0.130930
# Epoch 120, Test Loss: 0.144663, Train Loss: 0.130844
# Epoch 121, Test Loss: 0.144912, Train Loss: 0.130894
# Epoch 122, Test Loss: 0.144217, Train Loss: 0.130029
# Epoch 123, Test Loss: 0.143873, Train Loss: 0.129759
# Epoch 124, Test Loss: 0.141307, Train Loss: 0.132373
# Epoch 125, Test Loss: 0.159959, Train Loss: 0.131180
# Epoch 126, Test Loss: 0.144843, Train Loss: 0.130494
# Epoch 127, Test Loss: 0.143490, Train Loss: 0.130531
# Epoch 128, Test Loss: 0.141504, Train Loss: 0.133294
# Epoch 129, Test Loss: 0.141592, Train Loss: 0.129941
# Epoch 130, Test Loss: 0.142310, Train Loss: 0.132032
# Epoch 131, Test Loss: 0.143886, Train Loss: 0.129658
# Epoch 132, Test Loss: 0.143876, Train Loss: 0.132006
# Epoch 133, Test Loss: 0.146421, Train Loss: 0.131405
# Epoch 134, Test Loss: 0.144304, Train Loss: 0.127903
# Epoch 135, Test Loss: 0.145050, Train Loss: 0.128239
# Epoch 136, Test Loss: 0.143931, Train Loss: 0.130096
# Epoch 137, Test Loss: 0.141027, Train Loss: 0.128559
# Epoch 138, Test Loss: 0.139953, Train Loss: 0.129502
# Epoch 139, Test Loss: 0.146184, Train Loss: 0.128332
# Epoch 140, Test Loss: 0.144377, Train Loss: 0.127731
# Epoch 141, Test Loss: 0.142828, Train Loss: 0.130166
# Epoch 142, Test Loss: 0.139929, Train Loss: 0.128408
# Epoch 143, Test Loss: 0.145703, Train Loss: 0.129222
# Epoch 144, Test Loss: 0.146265, Train Loss: 0.129680
# Epoch 145, Test Loss: 0.149807, Train Loss: 0.130491
# Epoch 146, Test Loss: 0.141289, Train Loss: 0.128746
# Epoch 147, Test Loss: 0.139820, Train Loss: 0.129232
# Epoch 148, Test Loss: 0.146064, Train Loss: 0.127961
# Epoch 149, Test Loss: 0.140856, Train Loss: 0.127817
# Epoch 150, Test Loss: 0.141480, Train Loss: 0.129789
# Epoch 151, Test Loss: 0.142393, Train Loss: 0.127789
# Epoch 152, Test Loss: 0.141618, Train Loss: 0.128836
# Epoch 153, Test Loss: 0.145815, Train Loss: 0.128126
# Epoch 154, Test Loss: 0.140035, Train Loss: 0.128322
# Epoch 155, Test Loss: 0.144007, Train Loss: 0.129102
# Epoch 156, Test Loss: 0.143803, Train Loss: 0.129046
# Epoch 157, Test Loss: 0.151202, Train Loss: 0.127887
# Epoch 158, Test Loss: 0.145027, Train Loss: 0.127817
# Epoch 159, Test Loss: 0.142331, Train Loss: 0.128757
# Epoch 160, Test Loss: 0.144710, Train Loss: 0.128005
# Epoch 161, Test Loss: 0.140695, Train Loss: 0.128333
# Epoch 162, Test Loss: 0.138725, Train Loss: 0.128626
# Epoch 163, Test Loss: 0.141012, Train Loss: 0.127819
# Epoch 164, Test Loss: 0.141195, Train Loss: 0.127661
# Epoch 165, Test Loss: 0.139463, Train Loss: 0.126867
# Epoch 166, Test Loss: 0.141749, Train Loss: 0.127913
# Epoch 167, Test Loss: 0.141703, Train Loss: 0.127660
# Epoch 168, Test Loss: 0.141054, Train Loss: 0.128094
# Epoch 169, Test Loss: 0.144085, Train Loss: 0.126960
# Epoch 170, Test Loss: 0.138941, Train Loss: 0.126752
# Epoch 171, Test Loss: 0.139963, Train Loss: 0.127116
# Epoch 172, Test Loss: 0.144114, Train Loss: 0.126929
# Epoch 173, Test Loss: 0.139939, Train Loss: 0.127965
# Epoch 174, Test Loss: 0.142474, Train Loss: 0.127664
# Epoch 175, Test Loss: 0.138062, Train Loss: 0.126022
# Epoch 176, Test Loss: 0.141763, Train Loss: 0.126851
# Epoch 177, Test Loss: 0.139070, Train Loss: 0.126245
# Epoch 178, Test Loss: 0.141400, Train Loss: 0.124950
# Epoch 179, Test Loss: 0.149551, Train Loss: 0.127483
# Epoch 180, Test Loss: 0.138868, Train Loss: 0.125447
# Epoch 181, Test Loss: 0.143061, Train Loss: 0.126035
# Epoch 182, Test Loss: 0.140235, Train Loss: 0.126066
# Epoch 183, Test Loss: 0.146286, Train Loss: 0.126420
# Epoch 184, Test Loss: 0.141015, Train Loss: 0.125902
# Epoch 185, Test Loss: 0.149173, Train Loss: 0.126719
# Epoch 186, Test Loss: 0.141081, Train Loss: 0.126384
# Epoch 187, Test Loss: 0.138191, Train Loss: 0.124956
# Epoch 188, Test Loss: 0.140550, Train Loss: 0.125814
# Epoch 189, Test Loss: 0.139054, Train Loss: 0.126188
# Epoch 190, Test Loss: 0.142029, Train Loss: 0.126727
# Epoch 191, Test Loss: 0.145258, Train Loss: 0.125692
# Epoch 192, Test Loss: 0.145451, Train Loss: 0.125186
# Epoch 193, Test Loss: 0.140267, Train Loss: 0.126510
# Epoch 194, Test Loss: 0.143919, Train Loss: 0.124501
# Epoch 195, Test Loss: 0.141670, Train Loss: 0.126090
# Epoch 196, Test Loss: 0.138458, Train Loss: 0.125184
# Epoch 197, Test Loss: 0.138636, Train Loss: 0.126237
# Epoch 198, Test Loss: 0.139047, Train Loss: 0.125155
# Epoch 199, Test Loss: 0.146134, Train Loss: 0.125588
# Epoch 200, Test Loss: 0.140024, Train Loss: 0.125076
# Epoch 201, Test Loss: 0.140327, Train Loss: 0.126502
# Epoch 202, Test Loss: 0.141862, Train Loss: 0.124673
# Epoch 203, Test Loss: 0.139293, Train Loss: 0.125481
# Epoch 204, Test Loss: 0.139111, Train Loss: 0.124674
# Epoch 205, Test Loss: 0.144487, Train Loss: 0.124528
# Epoch 206, Test Loss: 0.141701, Train Loss: 0.125758
# Epoch 207, Test Loss: 0.144226, Train Loss: 0.124049
# Epoch 208, Test Loss: 0.150698, Train Loss: 0.125855
# Epoch 209, Test Loss: 0.143849, Train Loss: 0.125437
# Epoch 210, Test Loss: 0.141606, Train Loss: 0.124129
# Epoch 211, Test Loss: 0.139538, Train Loss: 0.124082
# Epoch 212, Test Loss: 0.142766, Train Loss: 0.124502
# Epoch 213, Test Loss: 0.137555, Train Loss: 0.124455
# Epoch 214, Test Loss: 0.144507, Train Loss: 0.125077
# Epoch 215, Test Loss: 0.140293, Train Loss: 0.124414
# Epoch 216, Test Loss: 0.139907, Train Loss: 0.124367
# Epoch 217, Test Loss: 0.143370, Train Loss: 0.122482
# Epoch 218, Test Loss: 0.140003, Train Loss: 0.123556
# Epoch 219, Test Loss: 0.153555, Train Loss: 0.125908
# Epoch 220, Test Loss: 0.136998, Train Loss: 0.123881
# Epoch 221, Test Loss: 0.140810, Train Loss: 0.123397
# Epoch 222, Test Loss: 0.140113, Train Loss: 0.123948
# Epoch 223, Test Loss: 0.145873, Train Loss: 0.123961
# Epoch 224, Test Loss: 0.136749, Train Loss: 0.124453
# Epoch 225, Test Loss: 0.143224, Train Loss: 0.123740
# Epoch 226, Test Loss: 0.138567, Train Loss: 0.122732
# Epoch 227, Test Loss: 0.141876, Train Loss: 0.123812
# Epoch 228, Test Loss: 0.137018, Train Loss: 0.122409
# Epoch 229, Test Loss: 0.141019, Train Loss: 0.123567
# Epoch 230, Test Loss: 0.140124, Train Loss: 0.122855
# Epoch 231, Test Loss: 0.141258, Train Loss: 0.123259
# Epoch 232, Test Loss: 0.143342, Train Loss: 0.123532
# Epoch 233, Test Loss: 0.140150, Train Loss: 0.121346
# Epoch 234, Test Loss: 0.140169, Train Loss: 0.122912
# Epoch 235, Test Loss: 0.141045, Train Loss: 0.123115
# Epoch 236, Test Loss: 0.152166, Train Loss: 0.122325
# Epoch 237, Test Loss: 0.140395, Train Loss: 0.122539
# Epoch 238, Test Loss: 0.141332, Train Loss: 0.123972
# Epoch 239, Test Loss: 0.139762, Train Loss: 0.124875
# Epoch 240, Test Loss: 0.141556, Train Loss: 0.123314
# Epoch 241, Test Loss: 0.139799, Train Loss: 0.122208
# Epoch 242, Test Loss: 0.141814, Train Loss: 0.122855
# Epoch 243, Test Loss: 0.140878, Train Loss: 0.122117
# Epoch 244, Test Loss: 0.136753, Train Loss: 0.121885
# Epoch 245, Test Loss: 0.139169, Train Loss: 0.122917
# Epoch 246, Test Loss: 0.143526, Train Loss: 0.121937
# Epoch 247, Test Loss: 0.140479, Train Loss: 0.121436
# Epoch 248, Test Loss: 0.142143, Train Loss: 0.121484
# Epoch 249, Test Loss: 0.143449, Train Loss: 0.122325
# Epoch 250, Test Loss: 0.138281, Train Loss: 0.121163
# Length of Training loss 250
# Length of Testing loss: 250

# %% [markdown]
# ___
# ### Apply it to one of the validation image

# %%
val_dataset = TIFFDataset('val-clean-tif', transform=transform) # Create the dataset for validation images
val_clean = val_dataset[0] # Load one clean image from the validation dataset
val_noisy = val_clean + (torch.randn_like(val_clean) * sig) # Add noise to the clean image
# val_denoised = model(val_noisy).detach() # Denoise the noisy image using the trained model
# val_clean_fft = torch.fft.fft2(val_clean)
val_noisy_4d = val_noisy.unsqueeze(0) # Add an extra dimension to represent the batch size
val_denoised = model(val_noisy_4d).detach() # Now pass this 4D tensor to the model

# Remove the batch dimension before further processing
val_denoised = val_denoised.squeeze(0)
val_clean_FFT = np.fft.fftn(val_clean)
val_noisy_fft = torch.fft.fftn(val_noisy)
val_denoised_fft = torch.fft.fftn(val_denoised)


# Your existing code to generate the figure and axes
fig, ax = plt.subplots(3, 3, figsize=(10, 7))

# Plot clean image
ax[0, 0].imshow(np.abs(val_clean).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[0, 0].set_title('clean image')
ax[0, 0].axis('off')

# Plot noisy image
ax[0, 1].imshow(np.abs(val_noisy).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[0, 1].set_title('noisy image')
ax[0, 1].axis('off')

# Plot denoised image
ax[0, 2].imshow(np.abs(val_denoised).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[0, 2].set_title('denoised image')
ax[0, 2].axis('off')

# Plot corresponding error images
ax[1, 0].imshow(3*np.abs(val_clean - val_clean).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[1, 0].axis('off')
ax[1, 0].text(0.02, 0.98, r'$\times 3$', transform=ax[1, 0].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 1].imshow(3*np.abs(val_clean - val_noisy).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[1, 1].axis('off')
ax[1, 1].text(0.02, 0.98, r'$\times 3$', transform=ax[1, 1].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 2].imshow(3*np.abs(val_clean - val_denoised).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[1, 2].axis('off')
ax[1, 2].text(0.02, 0.98, r'$\times 3$', transform=ax[1, 2].transAxes, fontsize=14, va='top', ha='left', color='white')

# Plot the Fourier transform of the clean image
ax[2, 0].imshow(np.log(np.abs(np.fft.fftshift(val_clean_FFT.squeeze()))**2), cmap='gray')
ax[2, 0].axis('off')

# Plot the Fourier transform of the noisy image
ax[2, 1].imshow(np.log(np.abs(np.fft.fftshift(val_noisy_fft.squeeze()))**2), cmap='gray')
ax[2, 1].axis('off')

# Plot the Fourier transform of the denoised image
ax[2, 2].imshow(np.log(np.abs(np.fft.fftshift(val_denoised_fft.squeeze()))**2), cmap='gray')
ax[2, 2].axis('off')


plt.tight_layout()
plt.show()

# %%
# define NMSE loss
def nmse_loss(output, target):
    diff = output - target
    diff_norm_squared = torch.sum(diff ** 2) ** (1/2)
    target_norm_squared = torch.sum(target ** 2) ** (1/2)
    nmse = diff_norm_squared / (target_norm_squared + 1e-8)  # Add a small constant to avoid division by zero
    return 20 * torch.log10(nmse)  # Convert to dB

# load in validation dataset
val_dataset = TIFFDataset('val-clean-tif', transform=transform) # Create the dataset for validation images
# Create a data loader for the validation dataset
val_loader = create_loader(val_dataset, batch_size)

test_dataset = TIFFDataset('test-clean-tif', transform=transform) # Create the dataset for validation images
test_loader = create_loader(test_dataset, 13)

# Evaluate performance on the validation set using NMSE
criterion = nmse_loss
model.eval()  # Set the model to evaluation mode
total_nmse = 0
with torch.no_grad():  # Disable gradient calculation for efficiency
    for i, val_batch in enumerate(test_loader):
        noisy_batch = val_batch + (torch.randn_like(val_batch) * sig)
        denoised_batch = model(noisy_batch)
        nmse = criterion(denoised_batch, val_batch)
        total_nmse += nmse.item()
nmse = total_nmse / len(test_loader)

print('Validation Normalized Mean Squared Error:', nmse)
print(min(100-5*(nmse+20.7), 100))

# Evaluate performance on the test set using SSIM
total_ssim = 0
criterion = ssim
with torch.no_grad():  # Disable gradient calculation for efficiency
    for i, val_batch in enumerate(test_loader):
        noisy_batch = val_batch + (torch.randn_like(val_batch) * sig)
        denoised_batch = model(noisy_batch)
        noisy_batch = noisy_batch.squeeze().numpy()
        denoised_batch = denoised_batch.squeeze().numpy()
        ssim_val = ssim(noisy_batch, denoised_batch, data_range=1)
        total_ssim += ssim_val
ssim_val = total_ssim / len(test_loader)

print('Test Structural Similarity Index:', ssim_val)
# Out:
# Validation Normalized Mean Squared Error: -19.617921829223633
# 94.58960914611816
# Test Structural Similarity Index: 0.658972295882478
